# %% [markdown]
#  # Trying to produce ML model for : MTCARS

# %% [markdown]
# 1. dataset =mtcars-Copy1.csv
# 2.target = obtain linear regression model
# 3.problem to counter = A] increase model accurecy ,
#                        B] try to  know which sequence of preprocessig of data will give me maximu model accrecy

# %% [markdown]
# 4.In this notbook am using preprocessing steps as follows :
#
# #  1.  NULL Check                            🏁
#
# #  2. Duplicates Check                   🏁
#
# #  3. Skewness Check                    🏁
#
# #  4. Outliers Check                        🏁
#
# #  5. Scaling  Check                        🏁
#
# #  6. Categorical Data Encoding Check     🏁

# %% [markdown]
# # 5. ultimately obtain final model accrecy more than 40 %

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('mtcars-Copy1.csv')

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
# Define steps to follow iin preprocessing of data:
#  1.  NULL Check                            🏁                   

#  2. Duplicates Check                   🏁

#  3. Skewness Check                    🏁                      

#  4. Outliers Check                        🏁                    

#  5. Scaling  Check                        🏁                   

#  6. Categorical Data Encoding Check     🏁

# %%
# 1.]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
df.shape
# Out:
# (32, 12)

# %%
df.count()
# Out:
# model    32
# mpg      32
# cyl      32
# disp     32
# hp       32
# drat     32
# wt       32
# qsec     32
# vs       32
# am       32
# gear     32
# carb     32
# dtype: int64

# %%
df['model'].describe()
# Out:
# count            32
# unique           32
# top       Mazda RX4
# freq              1
# Name: model, dtype: object

# %%
df.head(3)
# Out:
#            model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0      Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1  Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2     Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1

# %%
df.ndim
# Out:
# 2

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# # No need to drop any data

# %%
df.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
# No null va;lues found : clear to go ⏩

# %%
sns.heatmap(df.isnull())
plt.title("Null value visualization : No null values detected")
# Out:
# Text(0.5, 1.0, 'Null value visualization : No null values detected')

# %% [markdown]
# skipping : one hod encoding : to fill the null values

# %% [markdown]
# # 2.Duplicates Check......

# %%
df.drop_duplicates(keep=False,inplace=True)

# %%
df.shape
# Out:
# (32, 12)

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# No Duplicate values found:
# # 3. Skewness Check¶

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['mpg'],color='b')
plt.title('mpg data skewness: closly normal distribution')
# Out:
# Text(0.5, 1.0, 'mpg data skewness: closly normal distribution')

# %%
print('skew of data mpg: %f'% df['mpg'].skew())  
    
print(" Mpg data is :Moderately skewed")
# Out:
# skew of data mpg: 0.672377
#  Mpg data is :Moderately skewed

# %%
# no nedd to use log transform

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df.head(5)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['cyl'],color='g')
plt.title('cyl data skewness: closly normal distribution')
# Out:
# Text(0.5, 1.0, 'cyl data skewness: closly normal distribution')

# %%
print('skew of data cyl: %f'% df['cyl'].skew())

print("  data is :Moderately skewed")
# Out:
# skew of data cyl: -0.192261
#   data is :Moderately skewed

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['disp'],color='y')
plt.title('disp data skewness: closly normal distribution')
# Out:
# Text(0.5, 1.0, 'disp data skewness: closly normal distribution')

# %%
print('skew of data disp wt: %f'% df['disp'].skew())
print(" data is :Moderately skewed")
# Out:
# skew of data disp wt: 0.420233
#  data is :Moderately skewed

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['hp'],color='r')
plt.title('hp data skewness: closly normal distribution')
# Out:
# Text(0.5, 1.0, 'hp data skewness: closly normal distribution')

# %%
print('skew of data hp: %f'% df['hp'].skew())
print(" data is : moderatley skewed")
# Out:
# skew of data hp: 0.799407
#  data is : moderatley skewed

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['drat'],color='b')
plt.title('mpg data skewness: closly normal distribution')
# Out:
# Text(0.5, 1.0, 'mpg data skewness: closly normal distribution')

# %%
print('skew of data drat: %f'% df['drat'].skew())
print(" data is :close to normal ")
# Out:
# skew of data drat: 0.292780
#  data is :close to normal

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['wt'],color='y')
plt.title('wt data skewness: closly normal distribution')
# Out:
# Text(0.5, 1.0, 'wt data skewness: closly normal distribution')

# %%
print('skew of data wt: %f'% df['wt'].skew())
print(" data is :close to normal")
# Out:
# skew of data wt: 0.465916
#  data is :close to normal

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['qsec'],color='g')
plt.title('qsec data skewness: closly normal distribution')
# Out:
# Text(0.5, 1.0, 'qsec data skewness: closly normal distribution')

# %%
print('skew of data: %f'% df['qsec'].skew())
print(" data is :close to normal")
# Out:
# skew of data: 0.406347
#  data is :close to normal

# %% [markdown]
#  #No neet to use logtransofrm :
#
#  # 4.Outliers Detection and Removal Check :

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
plt.figure(figsize=(10,9))
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
# 1.mpg
# 2.hp
# 3. wt
# 4.qsec
# 5.carb

# %%
sns.boxplot(data=df,x=df['mpg'])
plt.title('outliers in mpg')
# Out:
# Text(0.5, 1.0, 'outliers in mpg')

# %%
sns.boxplot(data=df,x=df['hp'])
plt.title('outliers in hp')
# Out:
# Text(0.5, 1.0, 'outliers in hp')

# %%
sns.boxplot(data=df,x=df['wt'])
plt.title('outliers in wt')
# Out:
# Text(0.5, 1.0, 'outliers in wt')

# %%
sns.boxplot(data=df,x=df['qsec'])
plt.title('outliers in qsec')
# Out:
# Text(0.5, 1.0, 'outliers in qsec')

# %%
sns.boxplot(data=df,x=df['carb'])
plt.title('outliers in carb')
# Out:
# Text(0.5, 1.0, 'outliers in carb')

# %% [markdown]
# # Removing Outliers :  IQR method  mpg

# %%
# 1.mpg

# IQR  :

Q1=df['mpg'].quantile(0.25)
Q3=df['mpg'].quantile(0.75)
IQR=Q3-Q1
print("The 1st Quartile is: ",Q1)
print("The 3rd Quartile is: ", Q3)
print("My IQR is: ", IQR)


Lower_Whisker = Q1-1.5*IQR
Upper_Whisker = Q3+1.5*IQR


print("Lower Whisk. is: ",Lower_Whisker)
print("Upper Whisk. is:", Upper_Whisker)
# Out:
# The 1st Quartile is:  15.425
# The 3rd Quartile is:  22.8
# My IQR is:  7.375
# Lower Whisk. is:  4.362500000000001
# Upper Whisk. is: 33.8625

# %%
df[(df.mpg<Lower_Whisker)|(df.mpg>Upper_Whisker)]   # Imp step when unable to remove outilers , then adding this step might be usefull....
# Out:
#              model   mpg  cyl  disp  hp  drat     wt  qsec  vs  am  gear  carb
# 19  Toyota Corolla  33.9    4  71.1  65  4.22  1.835  19.9   1   1     4     1

# %%
df=df[df['mpg']<Upper_Whisker]

# %%
sns.boxplot(data=df,x=df["mpg"])
plt.title("Box-plot for mpg")
# Out:
# Text(0.5, 1.0, 'Box-plot for mpg')

# %%
sns.boxplot(data=df,x=df['hp'])
plt.title('Boxplot for hp')
# Out:
# Text(0.5, 1.0, 'Boxplot for hp')

# %%
plt.figure(figsize=(20,15))

plt.subplot(2,2,1)
df['hp'].hist(bins=50,label='hp_Distribution',alpha=0.99)
plt.axvline(np.mean(df['hp']),ls='--',c='r',label="Mean")
plt.axvline(np.median(df['hp']),ls=':',c='g',label="Median")
plt.ylabel("Counts")
plt.xlabel('hp_Distribution')
plt.legend()
plt.subplot(2,2,2)
plt.scatter(df['hp'],np.random.normal(7,0.2,size=df.shape[0]),alpha=0.55)
plt.title("hp_Distribution")

plt.subplot(2,2,3)
sns.boxplot(y='hp',data=df)
# Out:
# <AxesSubplot:ylabel='hp'>

# %%
# Removal of Outlier  : for hp
    
# IQR  :

Q1=df['hp'].quantile(0.25)
Q3=df['hp'].quantile(0.75)
IQR=Q3-Q1
print("The 1st Quartile is: ",Q1)
print("The 3rd Quartile is: ", Q3)
print("My IQR is: ", IQR)


Lower_Whisker = Q1-1.5*IQR
Upper_Whisker = Q3+1.5*IQR


print("Lower Whisk. is: ",Lower_Whisker)
print("Upper Whisk. is:", Upper_Whisker)
# Out:
# The 1st Quartile is:  101.0
# The 3rd Quartile is:  180.0
# My IQR is:  79.0
# Lower Whisk. is:  -17.5
# Upper Whisk. is: 298.5

# %%
df=df[df['hp']<Upper_Whisker]

# %%
sns.boxplot(data=df,x=df["hp"])
plt.title("Box-plot for hp")
# Out:
# Text(0.5, 1.0, 'Box-plot for hp')

# %%
# trimming the outliers :


new_df=df[df['hp']<Upper_Whisker]
new_df.shape
# Out:
# (30, 12)

# %%
# compair plots  :


plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.distplot(df['hp'])
plt.subplot(2,2,2)
sns.boxplot(df['hp'])
plt.subplot(2,2,3)
sns.distplot(new_df['hp'])
plt.subplot(2,2,4)
sns.boxplot(new_df['hp'])
plt.show()

# %%
sns.boxplot(data=df,x=df['qsec'])
# Out:
# <AxesSubplot:xlabel='qsec'>

# %%
plt.figure(figsize=(20,15))

plt.subplot(2,2,1)
df['qsec'].hist(bins=50,label='qsec_Distribution',alpha=0.99)
plt.axvline(np.mean(df['qsec']),ls='--',c='r',label="Mean")
plt.axvline(np.median(df['qsec']),ls=':',c='g',label="Median")
plt.ylabel("Counts")
plt.xlabel('qsec_Distribution')
plt.legend()
plt.subplot(2,2,2)
plt.scatter(df['qsec'],np.random.normal(7,0.2,size=df.shape[0]),alpha=0.55)
plt.title("qsec_Distribution")

plt.subplot(2,2,3)
sns.boxplot(y='qsec',data=df)
# Out:
# <AxesSubplot:ylabel='qsec'>

# %%
# Removal of Outlier  : method -1
    
# IQR  :

Q1=df['qsec'].quantile(0.25)
Q3=df['qsec'].quantile(0.75)
IQR=Q3-Q1
print("The 1st Quartile is: ",Q1)
print("The 3rd Quartile is: ", Q3)
print("My IQR is: ", IQR)


Lower_Whisker = Q1-1.5*IQR
Upper_Whisker = Q3+1.5*IQR


print("Lower Whisk. is: ",Lower_Whisker)
print("Upper Whisk. is:", Upper_Whisker)
# Out:
# The 1st Quartile is:  16.93
# The 3rd Quartile is:  18.8275
# My IQR is:  1.8975000000000009
# Lower Whisk. is:  14.083749999999998
# Upper Whisk. is: 21.673750000000002

# %%
df=df[df['qsec']<Upper_Whisker]

# %%
sns.boxplot(data=df,x=df["qsec"])
plt.title("Box-plot for qsec")
# Out:
# Text(0.5, 1.0, 'Box-plot for qsec')

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Hence all the Outliers removed : now expect higer accurecy 😍

# %% [markdown]
# # 5. Scaling Check ..

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# ...

# %%
df.head(3)
# Out:
#            model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0      Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1  Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2     Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1

# %% [markdown]
# # We  will try  to use encode categorical data 'model' into Numerical data : to use scalling technique
#
# Dont know how  it help  or it will execute or not .

# %%
df_cat=df.select_dtypes(object)

# %%
df_cat
# Out:
#                   model
# 0             Mazda RX4
# 1         Mazda RX4 Wag
# 2            Datsun 710
# 3        Hornet 4 Drive
# 4     Hornet Sportabout
# 5               Valiant
# 6            Duster 360
# 7             Merc 240D
# 9              Merc 280
# 10            Merc 280C
# 11           Merc 450SE
# 12           Merc 450SL
# 13          Merc 450SLC
# 14   Cadillac Fleetwood
# 15  Lincoln Continental
# 16    Chrysler Imperial
# 17             Fiat 128
# 18          Honda Civic
# 20        Toyota Corona
# 21     Dodge Challenger
# 22          AMC Javelin
# 23           Camaro Z28
# 24     Pontiac Firebird
# 25            Fiat X1-9
# 26        Porsche 914-2
# 27         Lotus Europa
# 28       Ford Pantera L
# 29         Ferrari Dino
# 31           Volvo 142E

# %%
568 137

# %%
# Using label encodeing to convert data into numerical data

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for col in df:
    le=LabelEncoder()
    
    df[col]=le.fit_transform(df[col])

# %%
df
# Out:
#     model  mpg  cyl  disp  hp  drat  wt  qsec  vs  am  gear  carb
# 0      16   14    1    10   8    14   7     4   0   1     1     3
# 1      17   14    1    10   8    14  10     8   0   1     1     3
# 2       4   17    0     4   4    13   5    20   1   1     1     0
# 3      12   15    1    13   8     4  13    22   1   0     0     0
# 4      13   11    2    19  12     5  15     8   0   0     0     1
# 5      27   10    1    12   6     0  16    26   1   0     0     0
# 6       6    2    2    19  17     6  18     3   0   0     0     3
# 7      18   18    0     9   1     9  12    24   1   0     1     1
# 9      19   12    1    11  10    15  15    17   1   0     1     3
# 10     20    9    1    11  10    15  15    21   1   0     1     3
# 11     21    7    2    14  13     3  23    11   0   0     0     2
# 12     22    8    2    14  13     3  19    13   0   0     0     2
# 13     23    4    2    14  13     3  20    16   0   0     0     2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   29 non-null     int32
#  1   mpg     29 non-null     int64
#  2   cyl     29 non-null     int64
#  3   disp    29 non-null     int64
#  4   hp      29 non-null     int64
#  5   drat    29 non-null     int64
#  6   wt      29 non-null     int64
#  7   qsec    29 non-null     int64
#  8   vs      29 non-null     int64
#  9   am      29 non-null     int64
#  10  gear    29 non-null     int64
#  11  carb    29 non-null     int64
# dtypes: int32(1), int64(11)
# memory usage: 2.8 KB

# %%
df.shape
# Out:
# (29, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   29 non-null     int64
#  1   mpg     29 non-null     int64
#  2   cyl     29 non-null     int64
#  3   disp    29 non-null     int64
#  4   hp      29 non-null     int64
#  5   drat    29 non-null     int64
#  6   wt      29 non-null     int64
#  7   qsec    29 non-null     int64
#  8   vs      29 non-null     int64
#  9   am      29 non-null     int64
#  10  gear    29 non-null     int64
#  11  carb    29 non-null     int64
# dtypes: int64(12)
# memory usage: 2.9 KB

# %%
# Hence we convert categorcial data into numerical data;

# %% [markdown]
# # Now we can use scalling :✅

# %%
df.head(2)
# Out:
#    model  mpg  cyl  disp  hp  drat  wt  qsec  vs  am  gear  carb
# 0     16   14    1    10   8    14   7     4   0   1     1     3
# 1     17   14    1    10   8    14  10     8   0   1     1     3

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
matplotlib.style.use('ggplot')

# %%
scaler = preprocessing.StandardScaler()
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
       'gear', 'carb'])  




# scalling of all columns :
# reason =  I just wanted to  covert  only 'model' data : it is sucessfull but unable to add just converted 'model'  data points to orignal dataset:
# so i use label encoding to complet dataset (df) : therefore my all data converted into new numerical datapoints
# so scalling the complet data set (trial and error)

# %%
df.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20, 10))

ax1.set_title('Before Scaling')

sns.kdeplot(df['model'], ax=ax1)
sns.kdeplot(df['mpg'], ax=ax1)
sns.kdeplot(df['cyl'], ax=ax1)

sns.kdeplot(df['disp'], ax=ax1)
sns.kdeplot(df['hp'], ax=ax1)
sns.kdeplot(df['drat'], ax=ax1)

sns.kdeplot(df['wt'], ax=ax1)
sns.kdeplot(df['qsec'], ax=ax1)
sns.kdeplot(df['vs'], ax=ax1)

sns.kdeplot(df['am'], ax=ax1)
sns.kdeplot(df['gear'], ax=ax1)
sns.kdeplot(df['carb'], ax=ax1)




ax2.set_title('After Scaling')

sns.kdeplot(df['model'], ax=ax2)
sns.kdeplot(df['mpg'], ax=ax2)
sns.kdeplot(df['cyl'], ax=ax2)

sns.kdeplot(df['disp'], ax=ax2)
sns.kdeplot(df['hp'], ax=ax2)
sns.kdeplot(df['drat'], ax=ax2)

sns.kdeplot(df['wt'], ax=ax2)
sns.kdeplot(df['qsec'], ax=ax2)
sns.kdeplot(df['vs'], ax=ax2)

sns.kdeplot(df['am'], ax=ax2)
sns.kdeplot(df['gear'], ax=ax2)
sns.kdeplot(df['carb'], ax=ax2)


plt.show()

# %%
df.corr()
# Out:
#           model       mpg       cyl      disp        hp      drat        wt  \
# model  1.000000  0.309299 -0.268376 -0.218183 -0.273329  0.077232 -0.082620
# mpg    0.309299  1.000000 -0.895553 -0.886750 -0.866103  0.615774 -0.872497
# cyl   -0.268376 -0.895553  1.000000  0.913109  0.884722 -0.661469  0.854076
# disp  -0.218183 -0.886750  0.913109  1.000000  0.842840 -0.660602  0.899807
# hp    -0.273329 -0.866103  0.884722  0.842840  1.000000 -0.468831  0.744663
# drat   0.077232  0.615774 -0.661469 -0.660602 -0.468831  1.000000 -0.728966
# wt    -0.082620 -0.872497  0.854076  0.899807  0.744663 -0.728966  1.000000
# qsec   0.320476  0.368637 -0.500998 -0.392161 -0.613783 -0.001406 -0.143223
# vs     0.242680  0.667206 -0.786046 -0.695300 -0.705833  0.402447 -0.554485
# am    -0.033976  0.645494 -0.621196 -0.674364 -0.453880  0.747918 -0.797388
# gear   0.069167  0.588809 -0.587820 -0.584392 -0.345084  0.749762 -0.720126
# ...

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(),cmap='CMRmap_r',annot=True)
plt.title("✅ Corellation between variables")
# Out:
# Text(0.5, 1.0, '✅ Corellation between variables')

# %% [markdown]
# # MAximum corellation :
#
# 1.model=mpg(31)
# 2.mpg = vs(67)
#
# 3.cyl= disp(91)
#
# 4.cyl=hp(88)
# 5.cyl=wt(85)
#
# 6.disp=hp(84)
#
# 7.hp=wt(74)

# %% [markdown]
# we chooes variabels  as our target s are
#
#
# # 91%     [ cyl  =  disp ]  ✅
#
#
# # 88%   [cyl=hp ]    ✅
#
#
# # 85%   [cyl=wt ]   ✅

# %%
#EDA


# With doing EDA we tend to understand that which variable is max.or min.correlated 

#  to our targeted variable {}.

# %% [markdown]
# # EDA

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,kind='reg',corner=True)

# %%
sns.jointplot(x='cyl',y='disp',data=df,kind='reg',color='b',height=5,ratio=2,marginal_ticks=True)

# %% [markdown]
# 91% [ cyl = disp ] ✅
# 88% [cyl=hp ] ✅
# 85% [cyl=wt ] ✅

# %%
sns.jointplot(x='cyl',y='hp',data=df,kind='reg',color='r',height=5,ratio=2,marginal_ticks=True)

# %%
sns.jointplot(x='cyl',y='wt',data=df,kind='reg',color='g',height=5,ratio=3,marginal_ticks=True)

# %%
sns.countplot(x='hp',data=df)
# Out:
# <AxesSubplot:xlabel='hp', ylabel='count'>

# %%
sns.countplot(x='cyl',data=df)
# Out:
# <AxesSubplot:xlabel='cyl', ylabel='count'>

# %%
sns.countplot(x='wt',data=df)
# Out:
# <AxesSubplot:xlabel='wt', ylabel='count'>

# %%
sns.scatterplot(x="cyl",y="wt",hue="hp",data=df)
# Out:
# <AxesSubplot:xlabel='cyl', ylabel='wt'>

# %%
sns.lmplot(x="cyl",y="wt",hue="hp",data=df)

# %% [markdown]
# # Simple Linear regression :

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # SLR :
#
# simple Linear regression :
#
#
# # Dependent var:  disp
# # Independent var:  cyl

# %%
A=df[['cyl']]   # Independent variable
B=df[['disp']]  # Dependent

# %% [markdown]
# #           Train              Test
#     A_train.              A_test.
#       B_train.              B_test.

# %%
# Train_ Test_Split:

A_train,A_test,B_train,B_test=train_test_split(A,B,test_size=0.20,random_state=0)

# %%
reg=LinearRegression()

# %%
# Deployed Simple Linear regression Model :

model=reg.fit(A_train,B_train)
model
# Out:
# LinearRegression()

# %%
B_train.shape,B_test.shape
# Out:
# ((23, 1), (6, 1))

# %%
A_train.shape,A_test.shape
# Out:
# ((23, 1), (6, 1))

# %%
model.intercept_      #values of constant'c'
# Out:
# array([4.42045455])

# %%
intercept=model.intercept_
intercept
# Out:
# array([4.42045455])

# %%
model.coef_
# Out:
# array([[6.71590909]])

# %%
coef=model.coef_
coef
# Out:
# array([[6.71590909]])

# %%
# Checking Model Accuracy 


model.score(A_train,B_train)
# Out:
# 0.8248342212650193

# %% [markdown]
# # Checking Model Accuracy  ✅😍😍🎉🥳= 82%

# %%
# Y=mx+c


# Taxable value (₹)    :  Dependent var.
# Invoice value (₹)   : Independent  var.


equation='cyl='+str(intercept)+'+disp*'+str(coef)
equation
# Out:
# 'cyl=[4.42045455]+disp*[[6.71590909]]'

# %% [markdown]
# # Prediction :😎😎

# %%
#      A=df[['cyl']]   # Independent variable
#      B=df[['disp']]  # Dependent



#          Train      Test
    
#  A       A_train.    A_test.

#  B       B_train.    B_test.

# %%
p_pred=model.predict(A_test)      # test results of Independnet variable

# %%
p_pred
# Out:
# array([[ 4.42045455],
#        [17.85227273],
#        [ 4.42045455],
#        [17.85227273],
#        [17.85227273],
#        [ 4.42045455]])

# %%
# Visualization  Of result ;


plt.scatter(np.array(A_test),B_test,color='blue')
plt.plot(np.array(A_test),np.array(p_pred),color='red',linewidth=3)
plt.title("Prediction Model Graph Applied on cyl")
plt.xlabel('Invoice Values in future ')
plt.ylabel("Estimated disp in Future");

# %% [markdown]
# SLR   by using another Libraire
# # Statsmodels :

# %% [markdown]
# import statsmodels.api as sm
# import statsmodels.formula.api as smf

# %%
#      A=df[['cyl']]   # Independent variable
#      B=df[['disp']]  # Dependent



#          Train      Test
    
#  A       A_train.    A_test.

#  B       B_train.    B_test.

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
A=sm.add_constant(A)
lm=sm.OLS(B,A)
model2=lm.fit()

# %%
model2

# %%
model2.summary
# Out:
# <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x00000219C1BA8BB0>>

# %%
model2.params
# Out:
# const    4.033762
# cyl      6.879421
# dtype: float64

# %%
# model Accuracy check :

model2.rsquared*100
# Out:
# 83.37688610536489

# %% [markdown]
# # 83% accurate model.😍🎉😎

# %%
# prediction :

# %%
model2.fittedvalues[0:50]
# Out:
# 0     10.913183
# 1     10.913183
# 2      4.033762
# 3     10.913183
# 4     17.792605
# 5     10.913183
# 6     17.792605
# 7      4.033762
# 9     10.913183
# 10    10.913183
# 11    17.792605
# 12    17.792605
# 13    17.792605
# 14    17.792605
# 15    17.792605
# 16    17.792605
# 17     4.033762
# 18     4.033762
# 20     4.033762
# 21    17.792605
# 22    17.792605
# 23    17.792605
# 24    17.792605
# 25     4.033762
# 26     4.033762
# 27     4.033762
# 28    17.792605
# 29    10.913183
# 31     4.033762
# dtype: float64

# %%
model2.predict()[0:15]
# Out:
# array([10.91318328, 10.91318328,  4.03376206, 10.91318328, 17.7926045 ,
#        10.91318328, 17.7926045 ,  4.03376206, 10.91318328, 10.91318328,
#        17.7926045 , 17.7926045 , 17.7926045 , 17.7926045 , 17.7926045 ])
